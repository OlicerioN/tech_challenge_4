# %%
# Lendo a base de dados

import pandas as pd
obesity = pd.read_csv('https://raw.githubusercontent.com/OlicerioN/tech_challenge_4/refs/heads/main/Obesity.csv?token=GHSAT0AAAAAADO7VJMQQQC6IAKH6ISMUR442ISS2UA')
obesity.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3    no   2.0   no  2.0  0.0  Frequently                Walking
# 4    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
# Verificando tipagem

obesity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          2111 non-null   object
#  1   Age             2111 non-null   float64
#  2   Height          2111 non-null   float64
#  3   Weight          2111 non-null   float64
#  4   family_history  2111 non-null   object
#  5   FAVC            2111 non-null   object
#  6   FCVC            2111 non-null   float64
#  7   NCP             2111 non-null   float64
#  8   CAEC            2111 non-null   object
#  9   SMOKE           2111 non-null   object
#  10  CH2O            2111 non-null   float64
#  11  SCC             2111 non-null   object
#  12  FAF             2111 non-null   float64
#  13  TUE             2111 non-null   float64
#  14  CALC            2111 non-null   object
#  15  MTRANS          2111 non-null   object
#  16  Obesity         2111 non-null   object
# ...

# %%
# Verificando características de colunas numéricas

obesity.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %%
# Verificando nulos por coluna

nulls = obesity.isnull().sum()
print(nulls)
# Out:
# Gender            0
# Age               0
# Height            0
# Weight            0
# family_history    0
# FAVC              0
# FCVC              0
# NCP               0
# CAEC              0
# SMOKE             0
# CH2O              0
# SCC               0
# FAF               0
# TUE               0
# CALC              0
# MTRANS            0
# Obesity           0
# dtype: int64

# %%
# Verificando linhas duplicadas

dup = obesity.duplicated().sum()
print('duplicated:', dup)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[68], line 3
#       1 # Verificando linhas duplicadas
# ----> 3 dup = obesity.duplicated().sum()
#       4 print('duplicated:', dup)
#
# AttributeError: 'function' object has no attribute 'duplicated'

# %%
# Removendo linhas duplicadas

obesity = obesity.drop_duplicates
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 3
#       1 # Removendo linhas duplicadas
# ----> 3 obesity = obesity.drop_duplicates
#
# AttributeError: 'function' object has no attribute 'drop_duplicates'

# %%
# Confirmando remoção das linhas duplicatas

dup_2 = obesity.duplicated()
dup_2 = dup_2.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[64], line 3
#       1 # Confirmando remoção das linhas duplicatas
# ----> 3 dup_2 = obesity.duplicated()
#       4 dup_2 = dup_2.sum()
#
# AttributeError: 'function' object has no attribute 'duplicated'

# %%
# Verificando valores possíveis e quantidades da variável Target

obesity['Obesity'].value_counts()
# Out:
# Obesity
# Obesity_Type_I         351
# Obesity_Type_III       324
# Obesity_Type_II        297
# Overweight_Level_I     290
# Overweight_Level_II    290
# Normal_Weight          287
# Insufficient_Weight    272
# Name: count, dtype: int64

# %%
obesity['FCVC'].value_counts()
# Out:
# FCVC
# 3.000000    652
# 2.000000    600
# 1.000000     33
# 2.971574      2
# 2.630137      2
#            ...
# 2.886260      1
# 2.658112      1
# 2.027574      1
# 1.123939      1
# 2.591439      1
# Name: count, Length: 810, dtype: int64
